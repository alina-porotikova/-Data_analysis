# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Задача" data-toc-modified-id="Задача-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Задача</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#План-работы" data-toc-modified-id="План-работы-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>План работы</a></span></li><li><span><a href="#Шаг-1.-Открыть-файлы-с-данными-и-изучить-общую-информацию.-Выполнить-предобработку-данных" data-toc-modified-id="Шаг-1.-Открыть-файлы-с-данными-и-изучить-общую-информацию.-Выполнить-предобработку-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Шаг 1. Открыть файлы с данными и изучить общую информацию. Выполнить предобработку данных</a></span><ul class="toc-item"><li><span><a href="#Журнал-сессий" data-toc-modified-id="Журнал-сессий-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Журнал сессий</a></span></li><li><span><a href="#Покупки" data-toc-modified-id="Покупки-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Покупки</a></span></li><li><span><a href="#Траты-на-рекламу" data-toc-modified-id="Траты-на-рекламу-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Траты на рекламу</a></span></li></ul></li><li><span><a href="#Шаг-2.-Задать-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Шаг-2.-Задать-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Шаг 2. Задать функции для расчёта и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функция-get_profiles()-—-для-создания-профилей-пользователей" data-toc-modified-id="Функция-get_profiles()-—-для-создания-профилей-пользователей-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Функция get_profiles() — для создания профилей пользователей</a></span></li><li><span><a href="#Функция-get_retention()-—-для-подсчёта-Retention-Rate" data-toc-modified-id="Функция-get_retention()-—-для-подсчёта-Retention-Rate-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Функция get_retention() — для подсчёта Retention Rate</a></span></li><li><span><a href="#Функция-get_conversion()-—-для-подсчёта-конверсии" data-toc-modified-id="Функция-get_conversion()-—-для-подсчёта-конверсии-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Функция get_conversion() — для подсчёта конверсии</a></span></li><li><span><a href="#Функция-get_ltv()-—-для-подсчёта-LTV" data-toc-modified-id="Функция-get_ltv()-—-для-подсчёта-LTV-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Функция get_ltv() — для подсчёта LTV</a></span></li><li><span><a href="#Функция-filter_data()-—-для-сглаживания-данных-при-построении-графиков" data-toc-modified-id="Функция-filter_data()-—-для-сглаживания-данных-при-построении-графиков-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Функция filter_data() — для сглаживания данных при построении графиков</a></span></li><li><span><a href="#Функция-plot_retention()-—-для-построения-графика-Retention-Rate" data-toc-modified-id="Функция-plot_retention()-—-для-построения-графика-Retention-Rate-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Функция plot_retention() — для построения графика Retention Rate</a></span></li><li><span><a href="#Функция-plot_conversion()-—-для-построения-графика-конверсии" data-toc-modified-id="Функция-plot_conversion()-—-для-построения-графика-конверсии-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Функция plot_conversion() — для построения графика конверсии</a></span></li><li><span><a href="#Функция-plot_ltv_roi-—-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-plot_ltv_roi-—-для-визуализации-LTV-и-ROI-6.8"><span class="toc-item-num">6.8&nbsp;&nbsp;</span>Функция plot_ltv_roi — для визуализации LTV и ROI</a></span></li></ul></li><li><span><a href="#Шаг-3.-Исследовательский-анализ-данных" data-toc-modified-id="Шаг-3.-Исследовательский-анализ-данных-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Шаг 3. Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Профили-пользователей" data-toc-modified-id="Профили-пользователей-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Профили пользователей</a></span></li><li><span><a href="#Из-каких-стран-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей?" data-toc-modified-id="Из-каких-стран-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей?-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей?</a></span></li><li><span><a href="#Какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи?" data-toc-modified-id="Какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи?-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи?</a></span></li><li><span><a href="#Из-каких-каналов-пришло-больше-всего-платящих-пользователей?" data-toc-modified-id="Из-каких-каналов-пришло-больше-всего-платящих-пользователей?-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Из каких каналов пришло больше всего платящих пользователей?</a></span></li></ul></li><li><span><a href="#Шаг-4.-Маркетинг" data-toc-modified-id="Шаг-4.-Маркетинг-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Шаг 4. Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Общая-сумма-расходов-на-маркетинг" data-toc-modified-id="Общая-сумма-расходов-на-маркетинг-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Общая сумма расходов на маркетинг</a></span></li><li><span><a href="#Как-траты-распределены-по-рекламным-источникам?" data-toc-modified-id="Как-траты-распределены-по-рекламным-источникам?-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Как траты распределены по рекламным источникам?</a></span></li><li><span><a href="#Визуализация-динамики-изменения-расходов-во-времени-(по-неделям-и-месяцам)-по-каждому-источнику" data-toc-modified-id="Визуализация-динамики-изменения-расходов-во-времени-(по-неделям-и-месяцам)-по-каждому-источнику-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Визуализация динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику</a></span></li><li><span><a href="#Cколько-в-среднем-стоило-привлечение-одного-пользователя-(CAC)-из-каждого-источника?" data-toc-modified-id="Cколько-в-среднем-стоило-привлечение-одного-пользователя-(CAC)-из-каждого-источника?-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Cколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника?</a></span></li></ul></li><li><span><a href="#Шаг-5.-Оценить-окупаемость-рекламы" data-toc-modified-id="Шаг-5.-Оценить-окупаемость-рекламы-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Шаг 5. Оценить окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Анализ-окупаемости-рекламы-c-помощью-графиков-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI" data-toc-modified-id="Анализ-окупаемости-рекламы-c-помощью-графиков-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Анализ окупаемости рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI</a></span></li><li><span><a href="#Проверка-конверсии-пользователей-и-динамики-её-изменения,-проверка-удержания-пользователей" data-toc-modified-id="Проверка-конверсии-пользователей-и-динамики-её-изменения,-проверка-удержания-пользователей-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Проверка конверсии пользователей и динамики её изменения, проверка удержания пользователей</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-странам-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по странам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по рекламным каналам</a></span></li></ul></li><li><span><a href="#Шаг-6.-Общий-вывод" data-toc-modified-id="Шаг-6.-Общий-вывод-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Шаг 6. Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Анализ убытков развлекательного приложения

# %% [markdown]
# ## Описание проекта
# Несмотря на огромные вложения в рекламу, последние несколько месяцев развлекательное приложение Procrastinate Pro+ терпит убытки. Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# - лог сервера с данными об их посещениях,
# - выгрузка их покупок за этот период,
# - рекламные расходы.
#
#
# ## Задача
#
# Разобраться в причинах убытков и помочь компании выйти в плюс.
# Нужно изучить:
# - откуда приходят пользователи и какими устройствами они пользуются,
# - сколько стоит привлечение пользователей из различных рекламных каналов;
# - сколько денег приносит каждый клиент,
# - когда расходы на привлечение клиента окупаются,
# - какие факторы мешают привлечению клиентов.

# %% [markdown]
# ## Описание данных
# В проекте использованы три датасета. Файл `visits_info_short.csv` хранит лог сервера с информацией о посещениях сайта, `orders_info_short.csv` — информацию о заказах, а `costs_info_short.csv` — информацию о расходах на рекламу.
#
# Структура `visits_info_short.csv`: \
# `User Id` — уникальный идентификатор пользователя, \
# `Region` — страна пользователя, \
# `Device` — тип устройства пользователя, \
# `Channel` — идентификатор источника перехода, \
# `Session Start` — дата и время начала сессии, \
# `Session End` — дата и время окончания сессии.
#
# Структура `orders_info_short.csv`: \
# `User Id` — уникальный идентификатор пользователя, \
# `Event Dt` — дата и время покупки, \
# `Revenue` — сумма заказа.
#
# Структура `costs_info_short.csv`: \
# `dt` — дата проведения рекламной кампании, \
# `Channel` — идентификатор рекламного источника, \
# `costs` — расходы на эту кампанию.

# %% [markdown]
# ## План работы
#
# Шаг 1. Открыть файлы с данными и изучить общую информацию. Выполнить предобработку данных
#
# Шаг 2. Задать функции для расчёта и анализа LTV, ROI, удержания и конверсии
#
# Шаг 3. Провести исследовательский анализ данных
# - составить профили пользователей, определить минимальную и максимальную даты привлечения пользователей
# - выяснить из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей, построить таблицу, отражающую количество пользователей и долю платящих из каждой страны
# - узнать какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи, построить таблицу, отражающую количество пользователей и долю платящих для каждого устройства
# - изучить рекламные источники привлечения и определить каналы, из которых пришло больше всего платящих пользователей, построить таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения
#
# Шаг 4. Маркетинг
# - посчитать общую сумму расходов на маркетинг
# - выяснить как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник
# - построить визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику
# - узнать сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника
#
# Шаг 5. Оценить окупаемость рекламы
# - используя графики LTV, ROI и CAC, проанализировать окупаемость рекламы. Считать, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения
# - проанализировать окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI
# - проверить конверсию пользователей и динамику её изменения. То же самое сделать с удержанием пользователей. Построить и изучить графики конверсии и удержания
# - проанализировать окупаемость рекламы с разбивкой по устройствам. Построить графики LTV и ROI, а также графики динамики LTV, CAC и ROI
# - проанализировать окупаемость рекламы с разбивкой по странам. Построить графики LTV и ROI, а также графики динамики LTV, CAC и ROI
# - проанализировать окупаемость рекламы с разбивкой по рекламным каналам. Построить графики LTV и ROI, а также графики динамики LTV, CAC и ROI
#
# Ответить на вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости?
#
# Шаг 6. Сделать общий вывод

# %% [markdown]
# ## Шаг 1. Открыть файлы с данными и изучить общую информацию. Выполнить предобработку данных

# %%
#импортируем необходимые библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, timedelta
import warnings

# %%
#сделаем красивый формат для дробных чисел
pd.set_option('display.float_format', '{:.2f}'.format)

#скроем возможные предупреждения
warnings.filterwarnings('ignore')

# %%
#прочитаем файлы с данными
visits = pd.read_csv('visits_info_short.csv') # гипотезы по увеличению выручки
orders = pd.read_csv('orders_info_short.csv') # покупки
costs = pd.read_csv('costs_info_short.csv')  # траты на рекламу

display(visits.head(5))
display(orders.head(5))
costs.head(5)
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom 113.30
# 1  2019-05-02  FaceBoom  78.10
# ...

# %%
# напишем функцию, чтобы изучить данные
def first_look(data):
    
    #изучим общую информацию о данных
    display(data.info())
    
    #посмотрим долю и количество пропусков
    display(pd.DataFrame({'sum_of_null': data.isna().sum(),
              'share_of_null': data.isna().mean()*100}))
    
    #проверим нет ли явных дубликатов
    print('Число дубликатов:', data.duplicated().sum())

# %% [markdown]
# ### Журнал сессий

# %%
first_look(visits)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52177 entries, 0 to 52176
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   User Id        52177 non-null  int64
#  1   Region         52177 non-null  object
#  2   Device         52176 non-null  object
#  3   Channel        52176 non-null  object
#  4   Session Start  52176 non-null  object
#  5   Session End    52176 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 2.4+ MB
# None
#                sum_of_null  share_of_null
# User Id                  0           0.00
# Region                   0           0.00
# Device                   1           0.00
# Channel                  1           0.00
# Session Start            1           0.00
# Session End              1           0.00
# Число дубликатов: 0

# %% [markdown]
# **Вывод:** пропусков и дубликатов в журнале сессий нет. Нужно изменить тип данных в столбцах "Session Start" и "Session End" на `datetime`, а также поменять названия столбцов.

# %%
# переименование столбцов
visits.columns=['user_id', 'region', 'device', 'channel', 'session_start', 'session_end']

# преобразование данных о времени
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])

# %% [markdown]
# ### Покупки

# %%
first_look(orders)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# None
#           sum_of_null  share_of_null
# User Id             0           0.00
# Event Dt            0           0.00
# Revenue             0           0.00
# Число дубликатов: 0

# %% [markdown]
# **Вывод:** пропусков и дубликатов в покупках нет. Нужно изменить тип данных в столбце "Event Dt" на `datetime`, а также поменять названия столбцов.

# %%
# переименование столбцов
orders.columns=['user_id', 'event_dt', 'revenue']

# преобразование данных о времени
orders['event_dt'] = pd.to_datetime(orders['event_dt'])

# %% [markdown]
# ### Траты на рекламу

# %%
first_look(costs)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
# None
#          sum_of_null  share_of_null
# dt                 0           0.00
# Channel            0           0.00
# costs              0           0.00
# Число дубликатов: 0

# %% [markdown]
# **Вывод:** пропусков и дубликатов в тратах на рекламу тоже нет. Нужно изменить тип данных в столбце "dt" на `datetime`, а также поменять названия столбцов.

# %%
# переименование столбцов
costs.columns=['dt', 'channel', 'costs']

# преобразование данных о времени
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# > **Вывод:** предобработка данных выполнена. Изменены названия столбцов и типы данных. Данные готовы для дальнейшего анализа.

# %% [markdown]
# ## Шаг 2. Задать функции для расчёта и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# ### Функция get_profiles() — для создания профилей пользователей

# %%
# функция для создания пользовательских профилей

def get_profiles(visits, orders, costs):

    # находим параметры первых посещений
    profiles = (
        visits.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {'session_start': 'first',
            'channel': 'first',
            'device': 'first',
            'region': 'first',}
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    costs = costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    costs['acquisition_cost'] = costs['costs'] / costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция get_retention() — для подсчёта Retention Rate

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция get_conversion() — для подсчёта конверсии

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция get_ltv() — для подсчёта LTV

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция filter_data() — для сглаживания данных при построении графиков

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция plot_retention() — для построения графика Retention Rate

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция plot_conversion() — для построения графика конверсии

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция plot_ltv_roi — для визуализации LTV и ROI

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# > **Вывод:** были заданы функции для вычисления значений метрик: \
# `get_profiles()` — для создания профилей пользователей, \
# `get_retention()` — для подсчёта Retention Rate (коэффициент удержания), \
# `get_conversion()` — для подсчёта конверсии, \
# `get_ltv()` — для подсчёта LTV (Lifetime Value, пожизненная ценность клиента). \
# \
# А также функции для построения графиков: \
# `filter_data()` — для сглаживания данных, \
# `plot_retention()` — для построения графика Retention Rate, \
# `plot_conversion()` — для построения графика конверсии, \
# `plot_ltv_roi` — для визуализации LTV и ROI (Return On Investment, окупаемость инвестиций).

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# ### Профили пользователей

# %%
# получаем профили пользователей
profiles = get_profiles(visits, orders, costs)
profiles.head()
# Out:
#     user_id            first_ts       channel   device         region  \
# 0    599326 2019-05-07 20:58:57      FaceBoom      Mac  United States
# 1  34186288 2019-05-09 17:29:23       organic  Android  United States
# 2  58263264 2019-05-11 19:18:43      FaceBoom   iPhone  United States
# 3  59835779 2019-05-11 21:13:47  MediaTornado   iPhone  United States
# 4  92610596 2019-05-31 21:28:36       organic  Android  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True              1.09
# 1  2019-05-09 2019-05-01  False              0.00
# 2  2019-05-11 2019-05-01  False              1.13
# 3  2019-05-11 2019-05-01  False              0.25
# 4  2019-05-31 2019-05-01  False              0.00

# %% [markdown]
# Считаем, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения.

# %%
# момент анализа
observation_date = datetime(2019, 11, 1).date()
print(observation_date)
# Out:
# 2019-11-01

# %%
# горизонт анализа
horizon_days = 14

# %%
# минимальная дата привлечения пользователей
min_analysis_date = costs['dt'].min()

# максимально возможная дата привлечения с учётом горизонта
max_analysis_date = observation_date - timedelta(days=horizon_days - 1)

print(min_analysis_date, max_analysis_date)
# Out:
# 2019-05-01 2019-10-19

# %%
# получим минимальную и максимальную даты из профилей пользователей
min_dt = profiles['dt'].min()
max_dt = profiles['dt'].max()
print(min_dt, max_dt)
# Out:
# 2019-05-01 2019-06-23

# %% [markdown]
# **Вывод:**
# - минимальная дата привлечения пользователей - 1 мая 2019
# - максимально возможная дата привлечения с учётом горизонта - 19 октября 2019
# - минимальную дата из профиля пользователей - 1 мая 2019
# - максимальная дата из профиля пользователей - 27 октября 2019
#
# Таким образом, даты из ТЗ заказчика входят в профили пользователей и мы можем проводить анализ дальше.

# %%
# напишем функцию, чтобы узнать долю платящих пользователей по каждому параметру
def share_of_payers(parametr):
    return (
        profiles.groupby(parametr).agg({'user_id': 'nunique', 'payer': ['sum','mean']})
        .droplevel(level=0, axis=1).rename(columns={'nunique':'number_of_users','sum':'number_of_payers', 
                                                    'mean':'share_of_payers'})
        .sort_values(by='share_of_payers', ascending=False).style.format({'share_of_payers':'{:.2%}'})
    )

# %% [markdown]
# ### Из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей?

# %%
share_of_payers('region')
# Out:
# <style type="text/css">
# </style>
# <table id="T_65ab8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65ab8_level0_col0" class="col_heading level0 col0" >number_of_users</th>
#       <th id="T_65ab8_level0_col1" class="col_heading level0 col1" >number_of_payers</th>
#       <th id="T_65ab8_level0_col2" class="col_heading level0 col2" >share_of_payers</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65ab8_level0_row0" class="row_heading level0 row0" >United States</th>
#       <td id="T_65ab8_row0_col0" class="data row0 col0" >28799</td>
#       <td id="T_65ab8_row0_col1" class="data row0 col1" >1771</td>
#       <td id="T_65ab8_row0_col2" class="data row0 col2" >6.15%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Вывод:** в развлекательном приложении Procrastinate Pro+ представлены пользователи из США, Германии, Великобритании и Франции. Больше всего пользователей приходится на США, меньше всего на Германию. Доля платящих пользователей (6,9%) больше всего тапкже в США, а меньше всего (3,8%) во Франции.

# %% [markdown]
# ### Какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи?

# %%
share_of_payers('device')
# Out:
# <style type="text/css">
# </style>
# <table id="T_0075e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0075e_level0_col0" class="col_heading level0 col0" >number_of_users</th>
#       <th id="T_0075e_level0_col1" class="col_heading level0 col1" >number_of_payers</th>
#       <th id="T_0075e_level0_col2" class="col_heading level0 col2" >share_of_payers</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >device</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0075e_level0_row0" class="row_heading level0 row0" >iPhone</th>
#       <td id="T_0075e_row0_col0" class="data row0 col0" >12971</td>
#       <td id="T_0075e_row0_col1" class="data row0 col1" >814</td>
#       <td id="T_0075e_row0_col2" class="data row0 col2" >6.28%</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# **Вывод:** клиенты приложения пользуются такими устройствами, как Mac, iPhone, Android и PC. Больше всего людей имеют iPhone, меньше всего - Mac. Однако, доля платящих пользователей выше всего (6,3%) у тех, кто пользуется Mac, ниже всего (5%) у пользователей PC.

# %% [markdown]
# ### Из каких каналов пришло больше всего платящих пользователей?

# %%
share_of_payers('channel')
# Out:
# <style type="text/css">
# </style>
# <table id="T_8b164">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b164_level0_col0" class="col_heading level0 col0" >number_of_users</th>
#       <th id="T_8b164_level0_col1" class="col_heading level0 col1" >number_of_payers</th>
#       <th id="T_8b164_level0_col2" class="col_heading level0 col2" >share_of_payers</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >channel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b164_level0_row0" class="row_heading level0 row0" >FaceBoom</th>
#       <td id="T_8b164_row0_col0" class="data row0 col0" >6645</td>
#       <td id="T_8b164_row0_col1" class="data row0 col1" >812</td>
#       <td id="T_8b164_row0_col2" class="data row0 col2" >12.22%</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# **Вывод:** Пользователи приходят в приложение из 10 рекламных источников. Больше всего пользователей приходит через "органический" трафик, то есть не через рекламу. На втором месте Faceboom, а на третьем - TipTop. Однако, доля платящих пользователей у "органического" трафика самая маленькая, всего лишь 2%. Наибольшая доля платящих пользователей (12,2%) у FaceBoom, далее идут AdNonSense (11,3%) и lambdaMediaAds (10,4%).

# %% [markdown]
# > **Вывод:**
# > - момент анализа проекта - 1 ноября 2019 года
# > - горизонт анализа - 14 дней
# > - минимальная дата привлечения пользователей - 1 мая 2019 года
# > - максимальная дата привлечения пользователей - 19 октября 2019 года
# >
# > Были составлены профили пользователей. Так, в развлекательном приложении Procrastinate Pro+ представлены пользователи из США, Германии, Великобритании и Франции. Больше всего пользователей приходится на США, меньше всего на Германию. Доля платящих пользователей (6,9%) больше всего тапкже в США, а меньше всего (3,8%) во Франции. \
# \
# Клиенты приложения пользуются такими устройствами, как Mac, iPhone, Android и PC. Больше всего людей имеют iPhone, меньше всего - Mac. Однако, доля платящих пользователей выше всего (6,3%) у тех, кто пользуется Mac, ниже всего (5%) у пользователей PC. \
# \
# Пользователи приходят в приложение из 10 рекламных источников. Больше всего пользователей приходит через "органический" трафик, то есть не через рекламу. На втором месте Faceboom, а на третьем - TipTop. Однако, доля платящих пользователей у "органического" трафика самая маленькая, всего лишь 2%. Наибольшая доля платящих пользователей (12,2%) у FaceBoom, далее идут AdNonSense (11,3%) и lambdaMediaAds (10,4%).

# %% [markdown]
# ## Шаг 4. Маркетинг

# %% [markdown]
# ### Общая сумма расходов на маркетинг

# %%
# посчитаем общую сумму расходов
round(costs['costs'].sum(),1)
# Out:
# 105497.3

# %% [markdown]
# **Вывод:** всего на маркетинг было потрачено 105 тысяч у.е.

# %% [markdown]
# ### Как траты распределены по рекламным источникам?

# %%
# посмотрим как траты распределены по каналам
advertising_cost = costs.groupby('channel').agg({'costs':'sum'}).sort_values(by='costs', ascending=False)
advertising_cost['share'] = advertising_cost['costs'] / advertising_cost['costs'].sum()
advertising_cost.style.format({'share':'{:.2%}', 'costs':'{:.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_9742f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9742f_level0_col0" class="col_heading level0 col0" >costs</th>
#       <th id="T_9742f_level0_col1" class="col_heading level0 col1" >share</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >channel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9742f_level0_row0" class="row_heading level0 row0" >TipTop</th>
#       <td id="T_9742f_row0_col0" class="data row0 col0" >54751.30</td>
#       <td id="T_9742f_row0_col1" class="data row0 col1" >51.90%</td>
#     </tr>
#     <tr>
#       <th id="T_9742f_level0_row1" class="row_heading level0 row1" >FaceBoom</th>
#       <td id="T_9742f_row1_col0" class="data row1 col0" >32445.60</td>
#       <td id="T_9742f_row1_col1" class="data row1 col1" >30.75%</td>
#     </tr>
# ...

# %% [markdown]
# **Вывод:** больше всего трат (51,9%) приходится на рекламный источник TipTop, на втором месте (30,7%) - FaceBoom, далее идут источники, на которые приходится незначительная доля рекламного бюджета (до 5%).

# %% [markdown]
# ### Визуализация динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику

# %%
# добавим столбцы с номером месяца и недели в таблицу
costs['week'] = pd.to_datetime(costs['dt']).dt.isocalendar().week
costs['month'] = pd.to_datetime(costs['dt']).dt.month

# %%
# построим графики
plt.figure(figsize=(15, 10))

ax1 = plt.subplot(2, 2, 1)
costs.pivot_table(index='week', columns='channel', values='costs', aggfunc='sum').plot(ax=ax1, grid=True, title='по неделям',
xlabel=('Номер недели'), ylabel=('Расходы'))

ax2 = plt.subplot(2, 2, 2, sharey = ax1)
costs.pivot_table(index='month', columns='channel', values='costs', aggfunc='sum').plot(ax=ax2, grid=True, legend=False, 
title='по месяцам', xlabel=('Номер месяца'))

plt.suptitle('Динамика изменения расходов во времени', fontsize=15);

# %% [markdown]
# **Вывод:** Как мы и выяснили ранее, в лидерах по расходам два источника: TipTop и FaceBoom. На графиках можно увидеть, что расходы на FaceBoom постепенно увеличиваются от месяца к месяцу, от недели к неделе. Расходы на TipTop от месяца к месяцу растут значительно реще и достигают своего пика в сентябре 2019 года. Расходы на остальные источники значительно меньше, поэтому уберем два лидера, чтобы посмотреть на них детальнее.

# %%
# сделаем срез таблицы без двух лидеров
cost = costs.query('channel != "TipTop" and channel != "FaceBoom"')

# построим графики
plt.figure(figsize=(15, 10))

ax1 = plt.subplot(2, 2, 1)
cost.pivot_table(index='week', columns='channel', values='costs', aggfunc='sum').plot(ax=ax1, grid=True, title='по неделям',
xlabel=('Номер недели'), ylabel=('Расходы')).legend(loc='upper left')

ax2 = plt.subplot(2, 2, 2, sharey = ax1)
cost.pivot_table(index='month', columns='channel', values='costs', aggfunc='sum').plot(ax=ax2, grid=True, legend=False, 
title='по месяцам', xlabel=('Номер месяца'))

plt.suptitle('Динамика изменения расходов во времени без двух лидеров', fontsize=15);

# %% [markdown]
# **Вывод:** на этих графиках можем увидеть, что наибольшие расходы от недели к неделе и от месяца к месяцу у WahooNetBanner, причем расходы постепенно растут. На втором месте расположился источник AdNonSense, расходы на который в мае значительно превышали расходы в октябре. Расходы на другие источники не сильно различаются.

# %% [markdown]
# ### Cколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника?

# %%
# строим график истории изменений CAC по каналам привлечения
profiles.pivot_table(index='dt', columns='channel', values='acquisition_cost', aggfunc='mean').plot(grid=True, figsize=(10, 5),
ylabel=('CAC'), xlabel=('Дата привлечения'), title=('Динамика САС по каналам привлечения')).legend(bbox_to_anchor=(1, 1));

# %% [markdown]
# **Вывод:** стоимость привлечения «органических» пользователей во всех когортах равна нулю, потому что они перешли в приложение Procrastinate Pro+ самостоятельно, а не благодаря рекламе. На графике явно видно, что стоимость привлечения одного пользователя через TipTop постоянно увеличивается и к ноябрю 2019 года увеличилась в 3,5 раза. Привлечение из других источников стабильно по стоимости и составляет от 0,25 до 1 у.е.

# %%
# посчитаем средний САС по каналам
display(profiles.pivot_table(index='channel', values='acquisition_cost', aggfunc='mean').sort_values(by='acquisition_cost', 
ascending=False))

# посчитаем средний САС по проекту
print('Средний САС по проекту:', round(profiles['acquisition_cost'].mean(),3))
# Out:
#                 acquisition_cost
# channel
# TipTop                      1.64
# FaceBoom                    1.11
# RocketSuperAds              0.54
# YRabbit                     0.26
# MediaTornado                0.22
# organic                     0.00
# Средний САС по проекту: 0.564

# %% [markdown]
# > **Вывод:** всего на маркетинг было потрачено 105 тысяч у.е.
# >
# >Больше всего трат (51,9%) приходится на рекламный источник TipTop, на втором месте (30,7%) - FaceBoom, далее идут источники, на которые приходится незначительная доля рекламного бюджета (до 5%).
# >
# >На графиках можно увидеть, что расходы на FaceBoom постепенно увеличиваются от месяца к месяцу, от недели к неделе. Расходы на TipTop от месяца к месяцу растут значительно реще и достигают своего пика в сентябре 2019 года. Расходы на остальные источники значительно меньше.
# >
# >Стоимость привлечения «органических» пользователей во всех когортах равна нулю, потому что они перешли в приложение Procrastinate Pro+ самостоятельно, а не благодаря рекламе. Стоимость привлечения одного пользователя через TipTop постоянно увеличивается и к ноябрю 2019 года увеличилась в 3,5 раза. Привлечение из других источников стабильно по стоимости и составляет от 0,25 до 1 у.е.

# %% [markdown]
# ## Шаг 5. Оценить окупаемость рекламы

# %% [markdown]
# ### Анализ окупаемости рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI

# %%
# исключим из профилей пользователей органических пользователей, поскольку нам нужно изучить именно окупаемость рекламы
profiles = profiles.query('channel != "organic"')

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(profiles, orders, observation_date, horizon_days)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# **Вывод:** из графиков можно сделать вывод, что ROI совсем не достигает точки безубыточности (100%), то есть вложенные в маркетинг средства не приносят никакой дополнительной прибыли бизнесу. Динамика ROI пользователей на 14-й день постоянно падает. Что касается LTV, этот показатель достаточно стабилен, значит, проблема не в ухудшении качества пользователей. Динамика стоимости привлечения пользователей (CAC) постоянно растет, рекламный бюджет увеличивается.
#
# Чтобы разобраться в причинах убытков развлекательного приложения Procrastinate Pro+, пройдём по всем доступным характеристикам пользователей — устройствам, стране и рекламным каналам.

# %% [markdown]
# ### Проверка конверсии пользователей и динамики её изменения, проверка удержания пользователей

# %%
# напишем функцию, чтобы узнать конверсию пользователей и динамику ее изменения
def conversion_rate(parametr):
    
    # смотрим конверсию с разбивкой по параметру
    dimensions=[parametr]
    conversion_raw, conversion_grouped, conversion_history = get_conversion(profiles, orders, observation_date, horizon_days, 
    dimensions=dimensions)

    # строим график
    return plot_conversion(conversion_grouped, conversion_history, horizon_days)

# напишем функцию, чтобы узнать удержание пользователей и динамику его изменения
def retention_rate(parametr):
    
    # смотрим удержание с разбивкой по параметру
    dimensions=[parametr]
    retention_raw, retention_grouped, retention_history = get_retention(profiles, visits, observation_date, horizon_days, 
    dimensions=dimensions)

    # строим график
    return plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# - разбивка по устройствам

# %%
conversion_rate('device')

# %%
retention_rate('device')

# %% [markdown]
# **Вывод:** на графиках видно, что лучше всего конвертируются пользователи продукции Apple (Mac и iPhone), немного хуже показывают результаты пользователи Android. А вот пользователи PC значительно отстают по сравнению с первыми тремя, хотя и не критично. Однако, платящие пользователи PC лучше всего удерживаются, хотя и нельзя сказать, что остальные три устройства показывают плохие результаты.

# %% [markdown]
# - разбивка по странам

# %%
conversion_rate('region')

# %%
retention_rate('region')

# %% [markdown]
# **Вывод:** Лучше всего конвертируются пользователи из США, но и хуже всего удерживаются. Конверсия и удержание пользователей из Германии, Великобритании и Франции почти не отличается.

# %% [markdown]
# - разбивка по рекламным каналам

# %% [markdown]
# Как мы помним, больше всего трат (51,9%) приходится на рекламный источник TipTop, на втором месте (30,7%) - FaceBoom, далее идут источники, на которые приходится незначительная доля рекламного бюджета (до 5%). Поэтому обратим особое внимание на TipTop и FaceBoom.

# %%
conversion_rate('channel')

# %%
retention_rate('channel')

# %% [markdown]
# **Вывод:** пользователи из FaceBoom конвертируются лучше всего, пользователи из TipTop расположились лишь на 4 месте, что не самый лучший показатель, учитывая то, что на TipTop уходит 51,9% рекламного бюджета. На втором и третьем месте по конверсии пользователей расположились источники AdNonSense и lambdaMediaAds. Что касается удержания почти все источники показывают хорошие результаты, за исключением двух. Это FaceBoom и AdNonSense. При этом у FaceBoom самое ужасное удержание пользователей, которое практически сводится к нулю, что является проблемой, учитывая, что на FaceBoom уходит 30,7% рекламного бюджета.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по устройствам

# %%
# напишем функцию, чтобы проанализировать окупаемость рекламы по параметрам
def ltv_roi(parametr):
    
    # считаем LTV и ROI с разбивкой по параметру
    dimensions = [parametr]
    ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(profiles, orders, observation_date, horizon_days, 
    dimensions=dimensions)

    # строим графики
    return plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %%
ltv_roi('device')

# %% [markdown]
# **Вывод:** лучше всего окупаются пользователи PC, далее идут пользователи Android, хотя они и не окупаются. Пользователи Mac и iPhone не окупаются вовсе, при том факте, что у них самая высокая динамика привлечения пользователей. В принципе, можно заметить, что динамика привлечения пользователей растет для всех устройств и влечет за собой снижение ROI у всех устройств. Динамика LTV пользователей везде стабильна. Значит, дело не в ухудшении качества пользователей.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по странам

# %%
ltv_roi('region')

# %% [markdown]
# **Вывод:** динамика LTV для всех стран стабильна, но подвержена сезонности. Франция, Германия и Великобритания имеют отличный показатель ROI и стабильную динамику ROI. Динамика стоимости привлечения пользователей из этих стран также не вызывает вопросов. Не окупается реклама только из США. Динамика стоимости привлечения пользователей из США имеет чудовищно большие значения и негативно влияет на динамику ROI.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по рекламным каналам

# %%
ltv_roi('channel')

# %% [markdown]
# **Вывод:** реклама не окупилась у 3 из 10 рекламных источников. При этом в эту тройку входят TipTop (51,9% рекламного бюджета) и FaceBoom (30,7% рекламного бюджета). Динамика стоимости привлечения пользователей стабильна у всех каналов, за исключением TipTop, расходы на который имеют гигантские масштабы, но не приводят к окупаемости.

# %% [markdown]
# >**Вывод:**
# >
# >**Окупается ли реклама, направленная на привлечение пользователей в целом?** \
# > — нет, в рассматриваемом периоде реклама не окупилась. ROI едва ли достигает точки безубыточности (100%), то есть вложенные в маркетинг средства не приносят никакой дополнительной прибыли бизнесу. Динамика ROI пользователей на 14-й день постоянно падает. Динамика стоимости привлечения пользователей (CAC) постоянно растет, рекламный бюджет увеличивается.
# >
# >**Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?** \
# > Пользователи Mac и iPhone не окупаются вовсе и хуже всего удерживаются, также у них самая высокая динамика привлечения пользователей.
# >
# > Из всех стран не окупается реклама только из США. Динамика стоимости привлечения пользователей из США имеет чудовищно большие значения и негативно влияет на динамику ROI. Также пользователи из этой страны хуже всего удерживаются.
# >
# > На TipTop и FaceBoom уходит 51,9% и 30,7% рекламного бюджета соответственно. Однако эти источники совсем не окупаются. При этом стоимость привлечения одного пользователя через TipTop постоянно увеличивается и за полгода увеличилась в 3,5 раза. А FaceBoom показывает наихудшие результаты по удержанию пользователей.
# >
# >**Чем могут быть вызваны проблемы окупаемости?** \
# >В целом проблемы окупаемости развлекательного приложения Procrastinate Pro+ вызваны неоправданно огромными расходами на привлечение пользователей в США на устройствах Mac и iPhone через рекламные каналы TipTop и FaceBoom.
# >
# > **Рекомендация для приложения Procrastinate Pro+** состоит в том, чтобы обратить внимание на другие рекламные источники, например, lambdaMediaAds, который прекрасно окупается, имеет стабильную динамику привлечения пользователей и наилучшие показатели LTV. При этом пользователи из этого рекламного источника неплохо конвертируются и удерживаются. Что касается стран, нужно сокращать неоправданные расходы на рекламу в США и обращать больше внимания на Германию, Великобританию и Францию. Также нужно сокращать расходы на привлечение пользователей через продукцию Apple, ведь рост динамики на привлечение пользователей сильно снижает показатель ROI.

# %% [markdown]
# ## Шаг 6. Общий вывод

# %% [markdown]
# В ходе предобработки данных были изменены названия столбцов и типы данных.
#
# Далее были заданы функции для вычисления значений метрик: \
# `get_profiles()` — для создания профилей пользователей, \
# `get_retention()` — для подсчёта Retention Rate (коэффициент удержания), \
# `get_conversion()` — для подсчёта конверсии, \
# `get_ltv()` — для подсчёта LTV (Lifetime Value, пожизненная ценность клиента). \
# \
# А также функции для построения графиков: \
# `filter_data()` — для сглаживания данных, \
# `plot_retention()` — для построения графика Retention Rate, \
# `plot_conversion()` — для построения графика конверсии, \
# `plot_ltv_roi` — для визуализации LTV и ROI (Return On Investment, окупаемость инвестиций).
#
# В ходе исследовательского анализа данных было установлено:
# - момент анализа проекта - 1 ноября 2019 года
# - горизонт анализа - 14 дней
# - минимальная дата привлечения пользователей - 1 мая 2019 года
# - максимальная дата привлечения пользователей - 19 октября 2019 года
#
# Были составлены профили пользователей. Так, в развлекательном приложении Procrastinate Pro+ представлены пользователи из США, Германии, Великобритании и Франции. Больше всего пользователей приходится на США, меньше всего на Германию. Доля платящих пользователей (6,9%) больше всего тапкже в США, а меньше всего (3,8%) во Франции.
#
# Клиенты приложения пользуются такими устройствами, как Mac, iPhone, Android и PC. Больше всего людей имеют iPhone, меньше всего - Mac. Однако, доля платящих пользователей выше всего (6,3%) у тех, кто пользуется Mac, ниже всего (5%) у пользователей PC.
#
# Пользователи приходят в приложение из 10 рекламных источников. Больше всего пользователей приходит через "органический" трафик, то есть не через рекламу. На втором месте Faceboom, а на третьем - TipTop. Однако, доля платящих пользователей у "органического" трафика самая маленькая, всего лишь 2%. Наибольшая доля платящих пользователей (12,2%) у FaceBoom, далее идут AdNonSense (11,3%) и lambdaMediaAds (10,4%).
#
# Далее было установлено, что всего на маркетинг было потрачено 105 тысяч у.е. Больше всего трат (51,9%) приходится на рекламный источник TipTop, на втором месте (30,7%) - FaceBoom, далее идут источники, на которые приходится незначительная доля рекламного бюджета (до 5%). Расходы на FaceBoom постепенно увеличиваются от месяца к месяцу, от недели к неделе. Расходы на TipTop от месяца к месяцу растут значительно реще и достигают своего пика в сентябре 2019 года. Расходы на остальные источники значительно меньше. Стоимость привлечения «органических» пользователей во всех когортах равна нулю, потому что они перешли в приложение Procrastinate Pro+ самостоятельно, а не благодаря рекламе. Стоимость привлечения одного пользователя через TipTop постоянно увеличивается и к ноябрю 2019 года увеличилась в 3,5 раза. Привлечение из других источников стабильно по стоимости и составляет от 0,25 до 1 у.е.
#
# **Был получен следующий вывод:**
#
# Реклама развлекательного приложения Procrastinate Pro+ не окупается и проблемы окупаемости вызваны неоправданно огромными расходами на привлечение пользователей в США на устройствах Mac и iPhone через рекламные каналы TipTop и FaceBoom.
#
# **Рекомендация для приложения Procrastinate Pro+ состоит в том, чтобы обратить внимание на другие рекламные источники, например, lambdaMediaAds, который прекрасно окупается, имеет стабильную динамику привлечения пользователей и наилучшие показатели LTV. При этом пользователи из этого рекламного источника неплохо конвертируются и удерживаются. Что касается стран, нужно сокращать неоправданные расходы на рекламу в США и обращать больше внимания на Германию, Великобританию и Францию. Также нужно сокращать расходы на привлечение пользователей через продукцию Apple, ведь рост динамики на привлечение пользователей сильно снижает показатель ROI.**
